# %%
# Dataset
display(dbutils.fs.ls("/databricks-datasets/definitive-guide/data/retail-data/all/"),truncate=False)

# %%
# %fs head dbfs:/databricks-datasets/definitive-guide/data/retail-data/all/online-retail-dataset.csv

# %%
# Write the data in form of delta table

df = spark.read.csv(path="dbfs:/databricks-datasets/definitive-guide/data/retail-data/all/online-retail-dataset.csv", inferSchema=True, header=True)
df.write.format("delta").mode("overwrite").partitionBy("country").saveAsTable("workspace.pyspark.sales_delta_before")
df.repartition(16).write.format("delta").mode("overwrite").partitionBy("country").saveAsTable("workspace.pyspark.sales_delta_partitioned")

# %%
# %sql
select * from workspace.pyspark.sales_delta_before

# %%
# %sql
select * from workspace.pyspark.sales_delta_partitioned

# %%
# %sql
select * from workspace.pyspark.sales_delta_before where InvoiceNo = '576394' and country = 'Australia'

# %%
# %sql
select * from workspace.pyspark.sales_delta_partitioned where InvoiceNo = '576394' and country = 'Australia'

# %%
# %sql

select min(invoiceno), max(invoiceno), _metadata.file_name from workspace.pyspark.sales_delta_before
group by _metadata.file_name
order by min(invoiceno)

# %%
spark.conf.set("spark.databricks.delta.optimize.maxFileSize", 64*1024*8)

# %%
# %sql
OPTIMIZE workspace.pyspark.sales_delta_partitioned where country = 'Australia' ZORDER BY (InvoiceNo)

# %%
# %sql

select min(invoiceno), max(invoiceno), _metadata.file_name from workspace.pyspark.sales_delta_partitioned
group by _metadata.file_name
order by min(invoiceno)

# %%
# %sql

select min(invoiceno), max(invoiceno), _metadata.file_name from workspace.pyspark.sales_delta_partitioned
group by _metadata.file_name
order by min(invoiceno)

# %%
# %sql

select country, min(invoiceno), max(invoiceno), _metadata.file_name from workspace.pyspark.sales_delta_partitioned
group by country, _metadata.file_name
order by country, min(invoiceno)

# %%
# %sql

select country, min(invoiceno), max(invoiceno), _metadata.file_name from workspace.pyspark.sales_delta_partitioned
group by country, _metadata.file_name
order by country, min(invoiceno)
