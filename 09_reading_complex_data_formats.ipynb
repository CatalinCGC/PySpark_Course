# %% [markdown]
# # Read parquet file

# %%
df_parquet = spark.read.format("parquet").load("data/input/sales_total_parquet/*.parquet")

# %%
df_parquet = spark.read.format("parquet").load("data/input/sales_total_orc/*.orc")
