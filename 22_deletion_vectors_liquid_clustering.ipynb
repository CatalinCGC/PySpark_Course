# %%
# %sql
CREATE TABLE workspace.bronze.sales AS
SELECT *
FROM 
read_files (
  'dbfs:/databricks-datasets/definitive-guide/data/retail-data/all/online-retail-dataset.csv',
  header => true,
  format => 'csv'
)

# %%
# %sql
select * from workspace.bronze.sales

# %%
# %sql
describe extended workspace.bronze.sales;

# %%
# %sql
ALTER TABLE workspace.bronze.sales SET TBLPROPERTIES (delta.enableDeletionVectors = False);

# %%
# %sql
describe extended workspace.bronze.sales;

# %%
# %sql
delete from workspace.bronze.sales where InvoiceNo = '540644';

# %%
# %sql
describe history workspace.bronze.sales;

# %%
# %sql
ALTER TABLE workspace.bronze.sales SET TBLPROPERTIES (delta.enableDeletionVectors = True);

# %%
# %sql
describe extended workspace.bronze.sales

# %%
# %sql
delete from workspace.bronze.sales where InvoiceNo = '536368';

# %%
# %sql
describe history workspace.bronze.sales

# %%
# %sql
ALTER TABLE workspace.bronze.sales CLUSTER BY (InvoiceNo);

# %%
# %sql
describe history workspace.bronze.sales

# %%
# %sql
ALTER TABLE workspace.bronze.sales CLUSTER BY None;

# %%
# %sql
describe history workspace.bronze.sales

# %%
# %sql
CREATE TABLE workspace.bronze.sales_ct CLUSTER BY (InvoiceNo) AS
SELECT *
FROM 
read_files (
  'dbfs:/databricks-datasets/definitive-guide/data/retail-data/all/online-retail-dataset.csv',
  header => true,
  format => 'csv'
)

# %%
# %sql
describe extended workspace.bronze.sales_ct

# %%
# %sql
select * from workspace.bronze.sales_ct where InvoiceNo = '536366'

# %%
# %sql
select * from workspace.bronze.sales where InvoiceNo = '536366'
